# %% [markdown]
# This notebook uses a vanilla (basic) Bayesian optimization algorithm to tackle an urban travel demand (i.e., origin-destination, OD) calibration problem. The traffic simulations are based on the SUMO simulator.

# %% [markdown]
# # SUMO configuration

# %% [markdown]
# **Mount GDrive**
#
# If you are working w/ colab rather than a jupyterlab notebook this drive mounting and sumo installation will need to be done every time you restart the runtime.

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# **Setup venv**

# %%
# %python -m venv .venv
# %source .venv/bin/activate

# %% [markdown]
# **Install SUMO**

# %%
# %sudo add-apt-repository -y ppa:sumo/stable
# %sudo apt-get update
# %sudo apt-get -y install sumo sumo-tools sumo-doc &

# %% [markdown]
# Set sumo env vars

# %%
# Set environment variable
import os
import sys
os.environ['SUMO_HOME'] = 'C:/Program Files (x86)/Eclipse/Sumo'
os.environ['LIBSUMO_AS_TRACI'] = '1' #Optional: for a huge performance boost (~8x) with Libsumo (No GUI)

if "SUMO_HOME" in os.environ:
    tools = os.path.join(os.environ["SUMO_HOME"], "tools")
    sys.path.append(tools)
else:
    sys.exit("Please declare the environment variable 'SUMO_HOME'")
#import traci

# %% [markdown]
# # Macros / utils

# %%
base_path = 'C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark'

# if base_path has a space in it, the sumo code will not work
if ' ' in base_path:
    raise ValueError("base_path should not contain spaces")

os.chdir(base_path)

# %%
# install missing packages
# %pip install -r requirements.txt

# %%
import os
import numpy as np
import pandas as pd
import pprint
import matplotlib.pyplot as plt
from pathlib import Path

import torch
from torch.quasirandom import SobolEngine

from botorch import fit_gpytorch_mll
from botorch.acquisition import qLogExpectedImprovement
from botorch.models import SingleTaskGP
from botorch.models.transforms import Standardize
from botorch.optim import optimize_acqf
from botorch.sampling.stochastic_samplers import StochasticSampler
from botorch.utils.transforms import unnormalize, normalize

from gpytorch.constraints import Interval
from gpytorch.kernels import MaternKernel, ScaleKernel
from gpytorch.likelihoods import GaussianLikelihood
from gpytorch.mlls import ExactMarginalLogLikelihood


from bayesian_optimization.helpers_sh import (load_kwargs_config,  ### <- helpers를 helpers_sh로 변경 (load_kwargs_config 함수의 마지막 input parameter를 제거하고 "sim_setup.json"을 추가함)
                    compute_nrmse_counts_all_edges, 
                    parse_loop_data_xml_to_pandas, 
                    create_taz_xml,
                    simulate_od,
                    od_xml_to_df,
                    )

# %%
config = load_kwargs_config(base_path, "bo_vanilla", "sim_setup_network1_SF_selectedEdges-v2.json")  ### <- 에서 , "sim_setup.json"를 제거함
Path(config["simulation_run_path"]).mkdir(parents=True, exist_ok=True)
pprint.pprint(dict(config))
# Out:
# {'BATCH_SIZE': 1,
#  'CPU_COUNTS': 8,
#  'EDGE_OUT_STR': 'edge_data.xml',
#  'NITER': 100,
#  'NUM_RESTARTS': 10,
#  'RAW_SAMPLES': 32,
#  'SAMPLE_SHAPE': 128,
#  'SUMO_PATH': 'C:/Program Files (x86)/Eclipse/Sumo',
#  'TRIPS2ODS_OUT_STR': 'trips.xml',
#  'additional_xml': WindowsPath('C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/network/network1_SF_selectedEdges-v2/additional.xml'),
#  'edge_selection': WindowsPath('C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/network/network1_SF_selectedEdges-v2/edge_selection.txt'),
#  'file_gt_od': WindowsPath('C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/network/network1_SF_selectedEdges-v2/od.xml'),
#  'fixed_routes': WindowsPath('C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/network/network1_SF_selectedEdges-v2/routes.csv'),
#  'model_name': 'bo_vanilla',
#  'n_init_search': 30,
#  'net_xml': WindowsPath('C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/network/network1_SF_selectedEdges-v2/net.xml'),
#  'network_name': 'network1_SF_selectedEdges-v2',
#  'network_path': WindowsPath('network/network1_SF_selectedEdges-v2'),
#  'od_duration_sec': 300,
#  'sim_end_time': 57600,
#  'sim_start_time': 54000,
#  'sim_stat_freq_sec': 300,
#  'simulation_run_path': 'output/network1_SF_selectedEdges-v2_bo_vanilla',
#  'taz2edge_xml': WindowsPath('C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/network/network1_SF_selectedEdges-v2/taz.xml')}

# %% [markdown]
# # Create GT (ground truth) scenario

# %%
# Get Ground Truth OD + fixed routes
print(f"Reading: {config['file_gt_od']}")
gt_od_df = od_xml_to_df(config["file_gt_od"])

print(f"Reading: {config['fixed_routes']}")
routes_df = pd.read_csv(config["fixed_routes"], index_col=0)

# if config["edge_selection"] exists
if "edge_selection" in config:
    if not os.path.exists(config["edge_selection"]):
        edge_selection = None
    else:
        print(f"Reading: {config['edge_selection']}")
        edge_selection = pd.read_csv(config["edge_selection"], header=None)
        edge_selection.columns = ["edge_id"]
        edge_selection = edge_selection["edge_id"].tolist()
else:
    edge_selection = None
# Out:
# Reading: C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\od.xml
# total GT demand:  6000.0
# Reading: C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\routes.csv
# Reading: C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\edge_selection.txt

# %% [markdown]
# Simulate the GT scenario to obtain the GT traffic statistics

# %%
simulation_gt_run_path =f'{config["simulation_run_path"]}/ground_truth'
prefix_output_gt = f'{simulation_gt_run_path}/sim'
sim_edge_out_gt = f'{prefix_output_gt}_{config["EDGE_OUT_STR"]}'
new_od_xml = f'{simulation_gt_run_path}/od.xml'

Path(simulation_gt_run_path).mkdir(parents=True, exist_ok=True)

base_od = gt_od_df.copy()
gt_od_vals = gt_od_df['count'].astype(float).to_numpy()
curr_od = gt_od_vals.copy()
base_od['count'] = curr_od
base_od = base_od.rename(columns={'fromTaz':'from', 'toTaz':'to'})        
create_taz_xml(new_od_xml, base_od, config["od_duration_sec"], base_path)
print(base_od)

# Run simulation
simulate_od(new_od_xml, 
            prefix_output_gt, 
            base_path, 
            config["net_xml"], 
            config["taz2edge_xml"], 
            config["additional_xml"],
            routes_df,
            config["sim_end_time"],
            config["TRIPS2ODS_OUT_STR"])
# Out:
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/ground_truth/od.xml
#        from        to   count  data
# 0  T1_680_1  T1_880_1  1000.0  None
# 1  T1_680_1  T1_101_2  2000.0  None
# 2  T1_680_1  T1_280_1   500.0  None
# 3  T1_680_1   T1_17_1  1500.0  None
# 4  T1_680_1  T1_101_1  1000.0  None
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/ground_truth/od.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/ground_truth/sim_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/ground_truth/sim_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/ground_truth/sim_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0

# %% [markdown]
# Read and process the GT simulation outputs

# %%
df_edge_gt, _, _ = parse_loop_data_xml_to_pandas(base_path, sim_edge_out_gt, prefix_output_gt, config["SUMO_PATH"], edge_list=edge_selection)
# picking at edges as GT edges
num_gt_edges = df_edge_gt.shape[0]
print("Number of GT edges:",num_gt_edges)
gt_edge_data = df_edge_gt\
    .sort_values(by=['interval_nVehContrib'], ascending=False)\
    .iloc[:num_gt_edges]

print(sim_edge_out_gt)
print(gt_edge_data)  # .head()
# Out:
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# Number of GT edges: 47
# output/network1_SF_selectedEdges-v2_bo_vanilla/ground_truth/sim_edge_data.xml
#          edge_id  interval_nVehContrib  interval_harmonicMeanSpeed
# 59    28378888#1                6000.0                       29.06
# 58    28378888#0                6000.0                       29.05
# 27      23955194                6000.0                       29.06
# 87      28464668                6000.0                       29.06
# 92      28588888                6000.0                       29.06
# 66      28413844                6000.0                       29.06
# 61    28396115#0                6000.0                       29.06
# 248    850615424                6000.0                       29.06
# 247    850615423                6000.0                       29.06
# 284    942228866                6000.0                       29.06
# 283    942219372                6000.0                       29.06
# 199    617284172                6000.0                       29.06
# 187    552389451                6000.0                       29.06
# 144    508115731                6000.0                       29.06
# 177  544296218#0                3000.0                       29.06
# 178  544296218#1                3000.0                       29.06
# 222    711193408                3000.0                       29.06
# 336    965603179                3000.0                       29.06
# 204    619042924                3000.0                       29.06
# 170     52286754                2000.0                       29.06
# 147    508115745                2000.0                       29.06
# 105     31559320                2000.0                       29.06
# 80      28432568                1500.0                       29.06
# 190     60723578                1500.0                       29.06
# 163     51383535                1500.0                       29.06
# 231    848429238                1500.0                       29.06
# 93      28665770                1500.0                       29.06
# 3      119271337                1500.0                       29.06
# 29     261596707                1500.0                       29.06
# 118    395336990                1500.0                       29.06
# 116    395336979                1500.0                       29.06
# 83      28437207                1000.0                       29.06
# 18     157806285                1000.0                       29.06
# 26      23807076                1000.0                       29.06
# 167    516535357                1000.0                       29.06
# 114    394385111                1000.0                       29.06
# 173     52305981                1000.0                       29.06
# 126    395368981                1000.0                       29.06
# 127    395368986                1000.0                       29.06
# 251    851548985                1000.0                       29.06
# 249    851520670                1000.0                       29.06
# 234    849677308                1000.0                       29.06
# 286    947247192                1000.0                       29.06
# 322    963455394                1000.0                       29.06
# 324    963455396                1000.0                       29.06
# 331    963510311                1000.0                       29.06
# 333    963510313                1000.0                       29.06

# %% [markdown]
# # Optimization
#
# Vanilla Bayesian Optimization (BO)

# %% [markdown]
# Bayesian optimization utils / helpers

# %%
def initialize_gp_model(train_X,train_Y):
    dim = train_X.size(dim=1)

    likelihood = GaussianLikelihood(noise_constraint=Interval(1e-8, 1e-3))
    covar_module = ScaleKernel(  # Use the same lengthscale prior as in the TuRBO paper
        MaternKernel(
            nu=2.5, ard_num_dims=dim, lengthscale_constraint=Interval(0.005, 4.0)
        )
    )

    gp_model = SingleTaskGP(
        train_X, train_Y,
        covar_module=covar_module, likelihood=likelihood,
        outcome_transform=Standardize(m=1)
    )

    gp_mll = ExactMarginalLogLikelihood(gp_model.likelihood, gp_model)

    return gp_model, gp_mll

def optimize_acqf_and_get_observation(acq_func, bounds, device, dtype, BATCH_SIZE, NUM_RESTARTS, RAW_SAMPLES):
    """Optimizes the acquisition function, and returns a new candidate."""

    dim = acq_func.model.train_inputs[0].size(dim=1)

    # optimize
    candidates, _ = optimize_acqf(
        acq_function=acq_func,
        bounds=torch.tensor([[0.0] * dim, [1.0] * dim], device=device, dtype=dtype),
        q=BATCH_SIZE,
        num_restarts=NUM_RESTARTS,
        raw_samples=RAW_SAMPLES,  # used for intialization heuristic
        options={"batch_limit": 5, "maxiter": 200},
    )

    # observe new values
    new_x = candidates.detach()

    return unnormalize(new_x, bounds)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
dtype = torch.double

dim_od = gt_od_df.shape[0]
print(dim_od)

bounds = torch.tensor([
    [ 0 for _ in range(dim_od)],
    [ 2000 for _ in range(dim_od)]
], device=device, dtype=dtype)
# Out:
# cpu
# 5

# %% [markdown]
# ## Create and simulate a sample of initial input points (i.e., ODs).

# %%
# Sample according to Sobol
sobol = SobolEngine(dim_od, scramble=True)
x_0 = sobol.draw(config["n_init_search"]).to(dtype=dtype).to(device)
# map the normalized into the original parameter space
train_X0 = unnormalize(x_0, bounds)

# %%
ods_epsilon = []
loss_all = []
batch_data_i = []

# Base OD which we will update their count entries
base_od = gt_od_df.copy()
gt_od_vals = gt_od_df['count'].astype(float).to_numpy()

for i , x in enumerate(train_X0.tolist()):
      print(f"########### OD: {i} ###########")
      print(x)
      
      simulation_run_path_init =f'{config["simulation_run_path"]}/initial_search'
      Path(simulation_run_path_init).mkdir(parents=True, exist_ok=True)
      
      new_od_xml = f"{simulation_run_path_init}/init_od_{config['network_name']}_{i}.xml"
      prefix_output_init = f'{simulation_run_path_init}/sobol_{i}'

      # Generate OD
      #curr_od = gt_od_vals.copy()
      curr_od = np.array(x)

      print(f'total expected GT demand: {np.sum(curr_od)}')

      ###
      # create OD xml file 
      ###
      base_od['count'] = curr_od
      # round to 1 decimal point
      base_od['count'] = [round(elem, 1) for elem in base_od['count']]     
      base_od = base_od.rename(columns={'fromTaz':'from', 'toTaz':'to'})        
      create_taz_xml(new_od_xml, base_od, config["od_duration_sec"], base_path)
      ods_epsilon.append(curr_od)

      # simulate initial search
      simulate_od(new_od_xml,
                  prefix_output_init,
                  base_path,
                  config["net_xml"], 
                  config["taz2edge_xml"], 
                  config["additional_xml"],
                  routes_df,
                  config["sim_end_time"],
                  config["TRIPS2ODS_OUT_STR"])

      ## Compute loss
      #prefix_output = f'initial_search/sobol_{i}'
      sim_edge_out = f'{base_path}/{prefix_output_init}_{config["EDGE_OUT_STR"]}'
      print(sim_edge_out)
      curr_loop_stats, _, _ = parse_loop_data_xml_to_pandas(base_path, sim_edge_out,prefix_output_init,config["SUMO_PATH"], edge_list=edge_selection)
      curr_loss = compute_nrmse_counts_all_edges(gt_edge_data, curr_loop_stats)

      loss_all.append(curr_loss)
      print(f"############## loss: {curr_loss} ##############")

      # Parse training data
      df_curr = pd.DataFrame(curr_od.reshape(1,dim_od),
                        columns = [f"x_{i+1}" for i in range(dim_od)])
      df_curr['loss'] = curr_loss
      batch_data_i.append(df_curr)

df_initial_bo = pd.concat(batch_data_i)
# Save initial dataset
df_initial_bo.to_csv(f"{simulation_run_path_init}/data_set_ods_0_2000.csv",index=None)
print(f"save df_initial_bo at {simulation_run_path_init}/data_set_ods_0_2000.csv")
# Out:
# ########### OD: 0 ###########
# [91.3718044757843, 1757.9436302185059, 429.69468235969543, 617.7873611450195, 795.1224446296692]
# total expected GT demand: 3691.9199228286743
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_0_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.487817239358364 ##############
# ########### OD: 1 ###########
# [1952.738881111145, 417.05578565597534, 1401.7744064331055, 1421.0577011108398, 1062.8186464309692]
# total expected GT demand: 6255.445420742035
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_1.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_1.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_1_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_1_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_1_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_1_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.1144724016353725 ##############
# ########### OD: 2 ###########
# [1207.077145576477, 1100.5631685256958, 534.0675115585327, 360.1994812488556, 1954.1491270065308]
# total expected GT demand: 5156.056433916092
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_2.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_2.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_2_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_2_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_2_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_2_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.33161028810340043 ##############
# ########### OD: 3 ###########
# [818.3834552764893, 693.148672580719, 1501.5019178390503, 1663.501262664795, 186.93313002586365]
# total expected GT demand: 4863.468438386917
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_3.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_3.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_3_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_3_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_3_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_3_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.3380188353432497 ##############
# ########### OD: 4 ###########
# [684.451162815094, 1335.0807428359985, 1246.1495399475098, 1803.4553527832031, 281.64592385292053]
# total expected GT demand: 5350.782722234726
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_4.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_4.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_4_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_4_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_4_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_4_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.2452136939429152 ##############
# ########### OD: 5 ###########
# [1295.8166599273682, 988.4552955627441, 218.16062927246094, 219.7570949792862, 1576.1750936508179]
# total expected GT demand: 4298.364773392677
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_5.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_5.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_5_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_5_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_5_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_5_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.4279537336149864 ##############
# ########### OD: 6 ###########
# [1552.232027053833, 1556.4231872558594, 1850.516676902771, 1061.4991188049316, 1468.1364297866821]
# total expected GT demand: 7488.807439804077
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_6.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_6.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_6_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_6_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_6_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_6_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.31761704204625374 ##############
# ########### OD: 7 ###########
# [413.5361313819885, 151.3282060623169, 817.897617816925, 977.8342843055725, 673.0660796165466]
# total expected GT demand: 3033.6623191833496
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_7.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_7.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_7_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_7_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_7_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_7_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.6390802458590862 ##############
# ########### OD: 8 ###########
# [265.58899879455566, 1245.6691265106201, 1971.5577363967896, 58.391273021698, 1216.8368101119995]
# total expected GT demand: 4758.043944835663
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_8.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_8.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_8_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_8_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_8_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_8_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.36819483818897303 ##############
# ########### OD: 9 ###########
# [1654.2848348617554, 586.5570306777954, 939.0073418617249, 1980.9497594833374, 922.2924113273621]
# total expected GT demand: 6083.091378211975
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_9.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_9.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_9_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_9_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_9_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_9_edge_data.xml
# ...
# ############## loss: 0.12681344589638455 ##############
# ########### OD: 27 ###########
# [692.7553415298462, 911.6860628128052, 610.1751923561096, 729.3921709060669, 1160.6212854385376]
# total expected GT demand: 4104.6300530433655
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_27.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_27.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_27_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_27_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_27_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_27_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.4173963276197709 ##############
# ########### OD: 28 ###########
# [812.039315700531, 1053.9805889129639, 138.02652060985565, 870.3227639198303, 1308.064579963684]
# total expected GT demand: 4182.433769106865
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_28.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_28.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_28_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_28_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_28_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_28_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.39703902029598404 ##############
# ########### OD: 29 ###########
# [1169.4847345352173, 644.9752449989319, 1170.1581478118896, 1168.4612035751343, 583.0778479576111]
# total expected GT demand: 4736.157178878784
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_29.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/init_od_network1_SF_selectedEdges-v2_29.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_29_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_29_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_29_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/sobol_29_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.2948709353838644 ##############
# save df_initial_bo at output/network1_SF_selectedEdges-v2_bo_vanilla/initial_search/data_set_ods_0_2000.csv

# %% [markdown]
# ## Run BO epochs

# %%
sampler = StochasticSampler(sample_shape=torch.Size([config["SAMPLE_SHAPE"]]))
df_0 = pd.read_csv(f"{config['simulation_run_path']}/initial_search/data_set_ods_0_2000.csv")

### Run loop
best_value = []

# Data frame of current training data
df_training = df_0
df_training["bo_iteration"] = 0

df_edge_stats = pd.DataFrame()

#num_epsilon_iter = 2
ods_epsilon = []
loss_all = []
batch_data_i = []

# Base OD which we will update their count entries
base_od = gt_od_df.copy()
gt_od_vals = gt_od_df['count'].astype(float).to_numpy()

# TODO for loop for multiple restarts
for i in range(config["NITER"]):
    # new_od_xml = f'{config["simulation_run_path"]}/od.xml'
    #   new_od_xml = f"{simulation_run_path_init}/init_od_{config['network_name']}_{i}.xml"
    #   prefix_output_init = f'{simulation_run_path_init}/sobol_{i}'

    simulation_run_path_BO =f'{config["simulation_run_path"]}/BO'
    Path(simulation_run_path_BO).mkdir(parents=True, exist_ok=True)

    ########
    # Start BO step
    ########

    print(f"########### BO iteration={i+1} ###########")

    # Obtain sampling locations x
    train_X = torch.from_numpy(
        df_training[[col for col in df_training.columns if "x" in col]].values
    ).to(device=device, dtype=dtype)

    # Normalize
    train_X_norm = normalize(train_X,bounds)

    # Obtain reponse data
    train_Y = -torch.from_numpy(df_training[["loss"]].values) # Take negative

    # best value so far
    best_y = train_Y.max()
    best_value.append(best_y)
    print(f"##### best_value={best_y} #####")

    print(f"Generating new sampling location(s)....")
    # Declare model with newest data
    gp_model, gp_mll = initialize_gp_model(train_X_norm,train_Y)

    # Fit model
    fit_gpytorch_mll(gp_mll)

    # Construct acquistion function
    # sampler = StochasticSampler(sample_shape=torch.Size([128]))
    qEI = qLogExpectedImprovement(gp_model, best_f=best_y, sampler=sampler)

    # Maximize acquisition function to get next observation
    x_i = optimize_acqf_and_get_observation(acq_func=qEI,
                                            bounds=bounds,
                                            device=device,
                                            dtype=dtype,
                                            BATCH_SIZE=config["BATCH_SIZE"],
                                            NUM_RESTARTS=config["NUM_RESTARTS"],
                                            RAW_SAMPLES=config["RAW_SAMPLES"])
    
    # if sum(x_i) == 0: skip remainder of loop
    if x_i.sum() == 0:
        print("All zeros, skipping loop")
        continue

    # map the normalized into the original parameter space
    #x_i = unnormalize(x_i, bounds)
    x_i = x_i.cpu().detach().numpy()

    ########
    # End BO step
    ########


    # Sample simulator (inner loop across all sampling locations within a batch)
    batch_data_i = []
    for j in range(config["BATCH_SIZE"]):
        loss_all = []
        print(f"########### Sampling location={j+1} ###########")

        new_od_xml_bo = f"{simulation_run_path_BO}/bayesOpt_od_{config['network_name']}_{i}_{j}.xml"
        prefix_output_bo = f'{simulation_run_path_BO}/bayesOpt_{i}_{j}'

        # Generate OD
        #curr_od = gt_od_vals.copy()
        curr_od = x_i[j]

        print(f'total expected GT demand: {np.sum(curr_od)}')

        base_od['count'] = curr_od
        # round to 1 decimal point
        base_od['count'] = [round(elem, 1) for elem in base_od['count']]
        base_od = base_od.rename(columns={'fromTaz':'from', 'toTaz':'to'})
        create_taz_xml(new_od_xml_bo, base_od, config["od_duration_sec"], base_path)

        # simulate gt od
        simulate_od(new_od_xml_bo,
                    prefix_output_bo,
                    base_path,
                    config["net_xml"],
                    config["taz2edge_xml"],
                    config["additional_xml"],
                    routes_df,
                    config["sim_end_time"],
                    config["TRIPS2ODS_OUT_STR"])

        ## Compute loss
        sim_edge_out = f'{base_path}/{prefix_output_bo}_{config["EDGE_OUT_STR"]}'
        print(sim_edge_out)
        curr_loop_stats, _, _ = parse_loop_data_xml_to_pandas(base_path, sim_edge_out,prefix_output_bo,config["SUMO_PATH"], edge_list=edge_selection)

        curr_loss = compute_nrmse_counts_all_edges(gt_edge_data, curr_loop_stats)
        loss_all.append(curr_loss)
        print(f"############## loss: {curr_loss} ##############")

        # Parse training data
        df_j = pd.DataFrame(x_i[j].reshape(1,dim_od),
                            columns = [f"x_{i+1}" for i in range(dim_od)])
        df_j['loss'] = curr_loss
        batch_data_i.append(df_j)

        curr_loop_stats['bo_iteration'] = i
        curr_loop_stats['batch'] = j
        df_edge_stats = pd.concat([df_edge_stats, curr_loop_stats])

    df_i = pd.concat(batch_data_i)
    df_i["bo_iteration"] = i+1

    df_training = pd.concat([df_training,df_i])
# Out:
# ########### BO iteration=1 ###########
# ##### best_value=-0.0893975172328356 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 7218.7675851168115
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_0_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_0_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_0_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_0_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_0_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_0_0_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.2672888380576488 ##############
# ########### BO iteration=2 ###########
# ##### best_value=-0.0893975172328356 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 6977.117452522469
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_1_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_1_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_1_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_1_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_1_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_1_0_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.24390850117702217 ##############
# ########### BO iteration=3 ###########
# ##### best_value=-0.0893975172328356 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 6201.842574759474
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_2_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_2_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_2_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_2_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_2_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_2_0_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.07723675691060405 ##############
# ########### BO iteration=4 ###########
# ##### best_value=-0.07723675691060405 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 5727.697652796703
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_3_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_3_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_3_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_3_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_3_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_3_0_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.14866099777561909 ##############
# ########### BO iteration=5 ###########
# ##### best_value=-0.07723675691060405 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 6617.193140991296
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_4_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_4_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_4_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_4_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_4_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_4_0_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.21223361441598337 ##############
# ########### BO iteration=6 ###########
# ##### best_value=-0.07723675691060405 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 5765.559691826914
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_5_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_5_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_5_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_5_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_5_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_5_0_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.0521903927420317 ##############
# ########### BO iteration=7 ###########
# ##### best_value=-0.0521903927420317 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 6047.635745280299
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_6_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_6_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_6_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_6_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_6_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_6_0_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.03405603538245308 ##############
# ########### BO iteration=8 ###########
# ##### best_value=-0.03405603538245308 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 6006.002486043116
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_7_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_7_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_7_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_7_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_7_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_7_0_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.05183045530713824 ##############
# ########### BO iteration=9 ###########
# ##### best_value=-0.03405603538245308 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 5754.298079657682
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_8_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_8_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_8_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_8_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_8_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_8_0_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.29928752449551305 ##############
# ########### BO iteration=10 ###########
# ##### best_value=-0.03405603538245308 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 5841.50889280068
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_9_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_9_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_9_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_9_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_9_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_9_0_edge_data.xml
# ...
# ############## loss: 0.10283031864367616 ##############
# ########### BO iteration=98 ###########
# ##### best_value=-0.0073283699988948075 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 5744.985634319855
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_97_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_97_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_97_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_97_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_97_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_97_0_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.06460625672794229 ##############
# ########### BO iteration=99 ###########
# ##### best_value=-0.0073283699988948075 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 6025.5012990284895
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_98_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_98_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_98_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_98_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_98_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_98_0_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.08433989502967577 ##############
# ########### BO iteration=100 ###########
# ##### best_value=-0.0073283699988948075 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 6140.294308443472
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_99_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\taz.xml --tazrelation-files output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_od_network1_SF_selectedEdges-v2_99_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_99_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_99_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_99_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\network1_SF_selectedEdges-v2\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/network1_SF_selectedEdges-v2_bo_vanilla/BO/bayesOpt_99_0_edge_data.xml
# Filtering edges to [['edge_id', '394385113', '394385111', '965883393', '28433666#0', '395362577', '966336760', '851544880', '394385114', '119271337', '28319616', '60759806', '848489711', '395336990', '23011290#0', '28437207', '963563480', '23807076', '848920992', '28319427', '699542380#1', '123592887#0', '23807653', '963510226', '851520670', '30637720', '24167679', '963510313', '1011949858', '23820853', '206086131', '963510311', '848501101', '851569274', '395337004', '867290381', '849806971', '955977953', '119271213', '516535357', '956168972', '28433451', '851548985', '617235603', '550284602', '28665770', '184867226', '550271868', '395336979', '963455414', '52305981', '867256163', '23807652', '963455403', '849677308', '963455396', '963510345', '956168973', '394449801', '28665763', '947247192', '848920992', '550284606', '24167679', '28319618#1', '395343260', '963455394', '875161026#0', '1011949858', '28435048', '4629955', '28413844', '394449801', '955977953', '60759792', '963585359', '550284591', '95265016#0', '395368986', '963383487', '617235596', '617259143', '867262165', '508060361', '28433666#0', '28433666#1', '52286754', '963383475', '848488831', '123592924#0', '28317945', '771071115', '28319423', '867256162', '6240693', '966336791', '28437383', '157806285', '963383473', '867259033', '963585337', '395368981', '28319423', '395394478', '28317747', '395368981', '394449802', '875161026#0', '867262165', '60723578', '28433666#1', '727202048', '961140459', '619042916', '11479094', '550271868', '851552197', '617284144', '849833093', '851552197', '395343763', '851552197', '617284143', '619042919', '28317747', '95264953', '963563456', '619042924', '508137802', '617259170', '91887987', '544296215#0', '28433451', '544296218#0', '123592887#0', '727202049', '727202049', '848467541', '848489712', '5018717', '956169006', '851556423', '544296218#1', '28434077', '956169006', '28379297', '28379297', '30959004', '30959004', '28437104', '711193408', '28414034', '961162563', '965603179', '699542380#1', '28433994#1', '28433994#1', '955990646', '28357402', '157782063', '28357386', '848743564', '848748039', '8947524', '8947524', '51383535', '848429238', '850760258', '965564181', '508060359', '95264987', '617235606', '1055899623', '23792499#0', '95264964', '23818708', '123555228', '28379297', '28433570', '28433570', '123555228', '550284598', '708615405', '42397233', '155667053', '52324493', '123867452', '28396119', '617284173', '848809833', '848818561', '617284164', '28464666', '848809834', '51383537', '961140461', '544299024', '28378882', '52286753', '52286753', '552389452', '617284165', '28378884#0', '508115737', '942206746', '942206746', '552389451', '617284172', '28588888', '850615423', '23955194', '942219372', '508115745', '28378888#1', '28378888#0', '28396115#0', '508115731', '942228866', '28464668', '28464668', '25029736', '367132267', '22372558', '848743565', '967501752', '848743564', '848743564', '26230994', '334904727', '25029732', '848745539', '25029706', '22372548', '848751591', '848748039', '848748039', '26230999#0', '22372547', '25029762', '26230999#1', '967501777', '367132265', '157750991#0', '850746591', '27807303', '850746591', '27807303', '848880058', '124952143', '479773100', '31559320', '6240691', '33104343', '42397233', '42397233', '28432568', '261596707', '28357178', '28357178', '942095960', '850615424']]
# ############## loss: 0.10593513285740534 ##############

# %% [markdown]
# Store outputs

# %%
print(f"saving at {config['simulation_run_path']}/BO/data_set_bayes_opt.csv")
df_training.to_csv(f"{config['simulation_run_path']}/BO/data_set_bayes_opt.csv",index=None)

print(f"saving at {config['simulation_run_path']}/BO/df_edge_stats.csv")
df_edge_stats.to_csv(f"{config['simulation_run_path']}/BO/df_edge_stats.csv",index=None)
# Out:
# saving at output/network1_SF_selectedEdges-v2_bo_vanilla/BO/data_set_bayes_opt.csv
# saving at output/network1_SF_selectedEdges-v2_bo_vanilla/BO/df_edge_stats.csv

# %% [markdown]
# # Results analysis

# %% [markdown]
# Read BO outputs

# %%
df_training = pd.read_csv(f"{config['simulation_run_path']}/BO/data_set_bayes_opt.csv")
df_edge_stats = pd.read_csv(f"{config['simulation_run_path']}/BO/df_edge_stats.csv")

# %% [markdown]
# Convergence plots

# %%
df_plot = df_training.query('bo_iteration>0')
x = df_plot['bo_iteration']
y = df_plot['loss'].cummin()

plt.plot(x, y)
#plt.legend(title='Parameter where:')
plt.xlabel('BO epoch')
plt.ylabel('Best NRMSE')
# plt.show()
plt.savefig(f"{config['simulation_run_path']}/bo_nrmse.png")

# %%
if df_edge_stats.batch.drop_duplicates().shape[0] > 1:
    raise('This needs updating once we start using batches')

losses = []
for o1 in range(config["NITER"]): #num_epsilon_iter):
    curr_edge_stats = df_edge_stats[df_edge_stats.bo_iteration == o1]
    df1b = gt_edge_data.merge(curr_edge_stats, on=['edge_id'], how='left', suffixes=('_gt', '_bo'))
    curr_loss = compute_nrmse_counts_all_edges(gt_edge_data, curr_edge_stats)
    losses.append(curr_loss)

# %% [markdown]
# Scatter plots: fit to traffic data
#
# Bar plots: fit to OD data

# %%
# disable interactive mode
plt.ioff()

if df_edge_stats.batch.drop_duplicates().shape[0] > 1:
    raise('This needs updating once we start using batches')

Path(f"{config['simulation_run_path']}/figs").mkdir(parents=True, exist_ok=True)

losses = []
for o1 in range(config["NITER"]): #num_epsilon_iter):
    curr_edge_stats = df_edge_stats[df_edge_stats.bo_iteration == o1]
    df1b = gt_edge_data.merge(curr_edge_stats, on=['edge_id'], how='left', suffixes=('_gt', '_bo'))
    curr_loss = compute_nrmse_counts_all_edges(gt_edge_data, curr_edge_stats)
    losses.append(curr_loss)

    # find idx of min loss
    idx_min = np.argmin(losses)
    o1 = idx_min

    curr_edge_stats = df_edge_stats[df_edge_stats.bo_iteration == o1]
    df1b = gt_edge_data.merge(curr_edge_stats, on=['edge_id'], how='left', suffixes=('_gt', '_bo'))
    curr_loss = compute_nrmse_counts_all_edges(gt_edge_data, curr_edge_stats)

    plt.figure()    
    # plotting diagonal line that represents a perfect data fit
    max_val = np.max([df1b.interval_nVehContrib_gt.max(), df1b.interval_nVehContrib_bo.max()])
    vec = np.arange(max_val)
    plt.plot(vec, vec, 'r-')
    plt.plot(df1b.interval_nVehContrib_gt, df1b.interval_nVehContrib_bo, 'x') 
    # plt.title(f'BO epochs: {o1}; loss: {curr_loss}')
    plt.xlabel('GT edge counts') 
    plt.ylabel('Simulated edge counts') 
    plt.savefig(f"{config['simulation_run_path']}/figs/{o1}_bo_edge_counts.png")


    # plot of fit to GT OD vs ET OD
    plt.figure()
    # get the OD values with the best loss
    curr_od = df_training.query('bo_iteration==@o1').iloc[0][[col for col in df_training.columns if "x" in col]].values
    # bar graph side by side by x axis
    width = 0.35
    plt.bar(np.arange(len(curr_od)), curr_od, width, label='BO')
    plt.bar(np.arange(len(gt_od_vals)) + width, gt_od_vals, width, label='GT')
    plt.legend()
    plt.xlabel('OD pair')
    plt.ylabel('Demand')
    # plt.title(f'BO iteration: {o1}')
    plt.savefig(f"{config['simulation_run_path']}/figs/{o1}_bo_od.png")
# Out:
# C:\Users\seung\AppData\Local\Temp\ipykernel_4188\3043882708.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %% [markdown]
# Save "Initial" iteration and "Best" iteration

# %%
# draw a joint seaborn plot for initial (o1 = 0) and best (o1 = idx_min) iteration
import seaborn as sns
import matplotlib.pyplot as plt

o1 = 0
curr_edge_stats = df_edge_stats[df_edge_stats.bo_iteration == o1]
df1b = gt_edge_data.merge(curr_edge_stats, on=['edge_id'], how='left', suffixes=('_gt', '_bo'))
curr_loss = compute_nrmse_counts_all_edges(gt_edge_data, curr_edge_stats)

idx_min = np.argmin(losses)
o2 = idx_min
curr_edge_stats = df_edge_stats[df_edge_stats.bo_iteration == o2]
df2b = gt_edge_data.merge(curr_edge_stats, on=['edge_id'], how='left', suffixes=('_gt', '_bo'))

# define another df to draw joint plot // hue = bo_iteration
df1b['bo_iteration'] = o1
df2b['bo_iteration'] = o2
df1b['type'] = 'initial'
df2b['type'] = 'best'

df_joint = pd.concat([df1b, df2b])

# plotting diagonal line that represents a perfect data fit
max_val = np.max([df1b.interval_nVehContrib_gt.max(), df1b.interval_nVehContrib_bo.max()])
vec = np.arange(max_val)

fig, ax = plt.subplots(nrows = 1 , ncols = 1, figsize=(5, 4))
# initial
sns.scatterplot(data=df1b, x='interval_nVehContrib_gt', y='interval_nVehContrib_bo',ax=ax)
# x label
ax.set_xlabel('GT edge counts')
# y label
ax.set_ylabel('Simulated edge counts')
ax.plot(vec, vec, 'r-')
plt.savefig(f"{config['simulation_run_path']}/{config['network_name']}_jointplot_initial.png")

fig, ax = plt.subplots(nrows = 1 , ncols = 1, figsize=(5, 4))
# best
sns.scatterplot(data=df2b, x='interval_nVehContrib_gt', y='interval_nVehContrib_bo',ax=ax)
# x label
ax.set_xlabel('GT edge counts')
# y label
ax.set_ylabel('Simulated edge counts')
ax.plot(vec, vec, 'r-')
plt.savefig(f"{config['simulation_run_path']}/{config['network_name']}_jointplot_best.png")

# %% [markdown]
# # ====================================================

# %%
# config["simulation_run_path"] - "bo_vanilla" + "gridsearch"
gridsearch_path = config["simulation_run_path"].replace("bo_vanilla", "gridsearch")

# %%
log_file_path = f'{gridsearch_path}/simulation_log.txt'
data = pd.read_csv(log_file_path, header=None)
len_col = data.shape[1]
data.columns = ["od_index", "loss"] + [f"od_{i}" for i in range(len_col-2)]
data.iloc[:,2:] = data.iloc[:,2:].map(lambda x: round(x, 1))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 log_file_path = f'{gridsearch_path}/simulation_log.txt'
# ----> 2 data = pd.read_csv(log_file_path, header=None)
#       3 len_col = data.shape[1]
#       4 data.columns = ["od_index", "loss"] + [f"od_{i}" for i in range(len_col-2)]
#
# File c:\Users\seung\anaconda3\envs\pyenv_311\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\seung\anaconda3\envs\pyenv_311\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\seung\anaconda3\envs\pyenv_311\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\seung\anaconda3\envs\pyenv_311\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\seung\anaconda3\envs\pyenv_311\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/network1_SF_gridsearch/simulation_log.txt'

# %%
# draw a heatmap
import seaborn as sns
import matplotlib.pyplot as plt

# data.od_0 : x-axis
# data.od_1 : y-axis
# data.loss : color
data_temp = data.copy()
# filter 250-750 and 650-1150
# data_temp = data_temp[(data_temp['od_0'] >= 250) & (data_temp['od_0'] <= 750)]
# data_temp = data_temp[(data_temp['od_1'] >= 650) & (data_temp['od_1'] <= 1150)]
fig, ax = plt.subplots(figsize=(10, 8))

heatmap_data = data_temp.pivot_table(index='od_1', columns='od_0', values='loss')
cax = ax.imshow(heatmap_data.values, aspect='auto', cmap='coolwarm', 
                extent=[heatmap_data.columns.min(), heatmap_data.columns.max(), 
                        heatmap_data.index.min(), heatmap_data.index.max()],
                        origin='lower')
fig.colorbar(cax)

# scatter df_training.x_1 df_training.x_2
df_plot = df_training.query('bo_iteration==0')
init_x = df_plot['x_1']
init_y = df_plot['x_2']
ax.scatter(init_x, init_y, color='green', marker='x', s=10, alpha = 0.3)

df_plot = df_training.query('bo_iteration>0')
# Initialize an empty list to hold the indices where the loss has improved
improved_indices = []

# Track the minimum loss observed so far
min_loss_so_far = float('inf')

# Iterate through each row in the filtered DataFrame
for idx, row in df_plot.iterrows():
    # If the current loss is lower than the minimum loss observed so far
    if row['loss'] < min_loss_so_far:
        # Update the minimum loss
        min_loss_so_far = row['loss']
        # Add the current index to the improved indices list
        improved_indices.append(idx)


df_improved = df_plot.loc[improved_indices]

# Get the x_1, x_2, and loss values from the improved rows
x = df_improved['x_1']
y = df_improved['x_2']
loss = df_improved['loss']
iter = df_improved['bo_iteration']

ax.plot(x, y, '-o', c='black', alpha = 0.5)
# put annotation of iter next to red points
for i, txt in enumerate(iter):
    ax.annotate(txt, (x.iloc[i], y.iloc[i]))

# final bo guess (min loss) x_1, x_2 in blue color
idx_min = df_training['loss'].idxmin()
df_final = df_training.loc[idx_min]
final_x = df_final['x_1']
final_y = df_final['x_2']

ax.scatter(final_x, final_y, color='red', marker='o', s=100)

plt.title('NRMSE heatmap')
# plt.show()
plt.savefig(f"{config['simulation_run_path']}/{config['network_name']}_NRMSE_heatmap.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 8
#       3 import matplotlib.pyplot as plt
#       5 # data.od_0 : x-axis
#       6 # data.od_1 : y-axis
#       7 # data.loss : color
# ----> 8 data_temp = data.copy()
#       9 # filter 250-750 and 650-1150
#      10 # data_temp = data_temp[(data_temp['od_0'] >= 250) & (data_temp['od_0'] <= 750)]
#      11 # data_temp = data_temp[(data_temp['od_1'] >= 650) & (data_temp['od_1'] <= 1150)]
#      12 fig, ax = plt.subplots(figsize=(10, 8))
#
# NameError: name 'data' is not defined

# %%
df_training

# %%
heatmap_data
