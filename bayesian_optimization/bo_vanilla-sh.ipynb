# %% [markdown]
# This notebook uses a vanilla (basic) Bayesian optimization algorithm to tackle an urban travel demand (i.e., origin-destination, OD) calibration problem. The traffic simulations are based on the SUMO simulator.

# %% [markdown]
# # SUMO configuration

# %% [markdown]
# **Mount GDrive**
#
# If you are working w/ colab rather than a jupyterlab notebook this drive mounting and sumo installation will need to be done every time you restart the runtime.

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# **Setup venv**

# %%
# %python -m venv .venv
# %source .venv/bin/activate

# %% [markdown]
# **Install SUMO**

# %%
# %sudo add-apt-repository -y ppa:sumo/stable
# %sudo apt-get update
# %sudo apt-get -y install sumo sumo-tools sumo-doc &

# %% [markdown]
# Set sumo env vars

# %%
# Set environment variable
import os
import sys
os.environ['SUMO_HOME'] = 'C:/Program Files (x86)/Eclipse/Sumo'
os.environ['LIBSUMO_AS_TRACI'] = '1' #Optional: for a huge performance boost (~8x) with Libsumo (No GUI)

if "SUMO_HOME" in os.environ:
    tools = os.path.join(os.environ["SUMO_HOME"], "tools")
    sys.path.append(tools)
else:
    sys.exit("Please declare the environment variable 'SUMO_HOME'")
#import traci

# %% [markdown]
# # Macros / utils

# %%
base_path = 'C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark'

# if base_path has a space in it, the sumo code will not work
if ' ' in base_path:
    raise ValueError("base_path should not contain spaces")

os.chdir(base_path)

# %%
# install missing packages
# %pip install -r requirements.txt

# %%
import os
import numpy as np
import pandas as pd
import pprint
import matplotlib.pyplot as plt
from pathlib import Path

import torch
from torch.quasirandom import SobolEngine

from botorch import fit_gpytorch_mll
from botorch.acquisition import qLogExpectedImprovement
from botorch.models import SingleTaskGP
from botorch.models.transforms import Standardize
from botorch.optim import optimize_acqf
from botorch.sampling.stochastic_samplers import StochasticSampler
from botorch.utils.transforms import unnormalize, normalize

from gpytorch.constraints import Interval
from gpytorch.kernels import MaternKernel, ScaleKernel
from gpytorch.likelihoods import GaussianLikelihood
from gpytorch.mlls import ExactMarginalLogLikelihood


from bayesian_optimization.helpers_sh import (load_kwargs_config,  ### <- helpers를 helpers_sh로 변경 (load_kwargs_config 함수의 마지막 input parameter를 제거하고 "sim_setup.json"을 추가함)
                    compute_nrmse_counts_all_edges, 
                    parse_loop_data_xml_to_pandas, 
                    create_taz_xml,
                    simulate_od,
                    od_xml_to_df,
                    )

# %%
config = load_kwargs_config(base_path, "bo_vanilla")  ### <- 에서 , "sim_setup.json"를 제거함
Path(config["simulation_run_path"]).mkdir(parents=True, exist_ok=True)
pprint.pprint(dict(config))
# Out:
# {'BATCH_SIZE': 1,
#  'CPU_COUNTS': 8,
#  'EDGE_OUT_STR': 'edge_data.xml',
#  'NITER': 100,
#  'NUM_RESTARTS': 10,
#  'RAW_SAMPLES': 32,
#  'SAMPLE_SHAPE': 128,
#  'SUMO_PATH': 'C:/Program Files (x86)/Eclipse/Sumo',
#  'TRIPS2ODS_OUT_STR': 'trips.xml',
#  'additional_xml': WindowsPath('C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/network/quickstart/additional.xml'),
#  'edge_selection': WindowsPath('C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/network/quickstart/edge_selection.txt'),
#  'file_gt_od': WindowsPath('C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/network/quickstart/od.xml'),
#  'fixed_routes': WindowsPath('C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/network/quickstart/routes.csv'),
#  'model_name': 'bo_vanilla',
#  'n_init_search': 30,
#  'net_xml': WindowsPath('C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/network/quickstart/net.xml'),
#  'network_name': 'quickstart',
#  'network_path': WindowsPath('network/quickstart'),
#  'od_duration_sec': 300,
#  'sim_end_time': 57600,
#  'sim_start_time': 54000,
#  'sim_stat_freq_sec': 300,
#  'simulation_run_path': 'output/quickstart_bo_vanilla',
#  'taz2edge_xml': WindowsPath('C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/network/quickstart/taz.xml')}

# %% [markdown]
# # Create GT (ground truth) scenario

# %%
# Get Ground Truth OD + fixed routes
print(f"Reading: {config['file_gt_od']}")
gt_od_df = od_xml_to_df(config["file_gt_od"])

print(f"Reading: {config['fixed_routes']}")
routes_df = pd.read_csv(config["fixed_routes"], index_col=0)

# if config["edge_selection"] exists
if "edge_selection" in config:
    if not os.path.exists(config["edge_selection"]):
        edge_selection = None
    else:
        print(f"Reading: {config['edge_selection']}")
        edge_selection = pd.read_csv(config["edge_selection"], header=None)
        edge_selection.columns = ["edge_id"]
        edge_selection = edge_selection["edge_id"].tolist()
else:
    edge_selection = None
# Out:
# Reading: C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\od.xml
# total GT demand:  2800.0
# Reading: C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\routes.csv

# %% [markdown]
# Simulate the GT scenario to obtain the GT traffic statistics

# %%
simulation_gt_run_path =f'{config["simulation_run_path"]}/ground_truth'
prefix_output_gt = f'{simulation_gt_run_path}/sim'
sim_edge_out_gt = f'{prefix_output_gt}_{config["EDGE_OUT_STR"]}'
new_od_xml = f'{simulation_gt_run_path}/od.xml'

Path(simulation_gt_run_path).mkdir(parents=True, exist_ok=True)

base_od = gt_od_df.copy()
gt_od_vals = gt_od_df['count'].astype(float).to_numpy()
curr_od = gt_od_vals.copy()
base_od['count'] = curr_od
base_od = base_od.rename(columns={'fromTaz':'from', 'toTaz':'to'})        
create_taz_xml(new_od_xml, base_od, config["od_duration_sec"], base_path)
print(base_od)

# Run simulation
simulate_od(new_od_xml, 
            prefix_output_gt, 
            base_path, 
            config["net_xml"], 
            config["taz2edge_xml"], 
            config["additional_xml"],
            routes_df,
            config["sim_end_time"],
            config["TRIPS2ODS_OUT_STR"])
# Out:
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/ground_truth/od.xml
#     from     to  count  data
# 0  taz91  taz93  500.0  None
# 1  taz91  taz94  500.0  None
# 2  taz92  taz93  900.0  None
# 3  taz92  taz94  900.0  None
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/ground_truth/od.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/ground_truth/sim_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/ground_truth/sim_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/ground_truth/sim_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0

# %% [markdown]
# Read and process the GT simulation outputs

# %%
df_edge_gt, _, _ = parse_loop_data_xml_to_pandas(base_path, sim_edge_out_gt, prefix_output_gt, config["SUMO_PATH"], edge_list=edge_selection)
# picking at edges as GT edges
num_gt_edges = df_edge_gt.shape[0]
print("Number of GT edges:",num_gt_edges)
gt_edge_data = df_edge_gt\
    .sort_values(by=['interval_nVehContrib'], ascending=False)\
    .iloc[:num_gt_edges]

print(sim_edge_out_gt)
print(gt_edge_data)  # .head()
# Out:
# Number of GT edges: 14
# output/quickstart_bo_vanilla/ground_truth/sim_edge_data.xml
#    edge_id  interval_nVehContrib  interval_harmonicMeanSpeed
# 1       D4                1800.0                    8.565714
# 6      L14                1800.0                   11.332500
# 11      L4                1800.0                   10.398750
# 3       D7                1400.0                   11.387778
# 4      L10                1400.0                   11.453750
# 2       D5                1400.0                   11.542500
# 13      L7                1400.0                   11.141111
# 9      L18                1400.0                   11.456250
# 12      L5                1400.0                   11.266250
# 0       D2                1000.0                    8.665000
# 5      L12                1000.0                   11.510000
# 10      L2                1000.0                   10.390000
# 8      L16                 900.0                   12.070000
# 7      L15                 500.0                   11.952000

# %% [markdown]
# # Optimization
#
# Vanilla Bayesian Optimization (BO)

# %% [markdown]
# Bayesian optimization utils / helpers

# %%
def initialize_gp_model(train_X,train_Y):
    dim = train_X.size(dim=1)

    likelihood = GaussianLikelihood(noise_constraint=Interval(1e-8, 1e-3))
    covar_module = ScaleKernel(  # Use the same lengthscale prior as in the TuRBO paper
        MaternKernel(
            nu=2.5, ard_num_dims=dim, lengthscale_constraint=Interval(0.005, 4.0)
        )
    )

    gp_model = SingleTaskGP(
        train_X, train_Y,
        covar_module=covar_module, likelihood=likelihood,
        outcome_transform=Standardize(m=1)
    )

    gp_mll = ExactMarginalLogLikelihood(gp_model.likelihood, gp_model)

    return gp_model, gp_mll

def optimize_acqf_and_get_observation(acq_func, bounds, device, dtype, BATCH_SIZE, NUM_RESTARTS, RAW_SAMPLES):
    """Optimizes the acquisition function, and returns a new candidate."""

    dim = acq_func.model.train_inputs[0].size(dim=1)

    # optimize
    candidates, _ = optimize_acqf(
        acq_function=acq_func,
        bounds=torch.tensor([[0.0] * dim, [1.0] * dim], device=device, dtype=dtype),
        q=BATCH_SIZE,
        num_restarts=NUM_RESTARTS,
        raw_samples=RAW_SAMPLES,  # used for intialization heuristic
        options={"batch_limit": 5, "maxiter": 200},
    )

    # observe new values
    new_x = candidates.detach()

    return unnormalize(new_x, bounds)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
dtype = torch.double

dim_od = gt_od_df.shape[0]
print(dim_od)

bounds = torch.tensor([
    [ 0 for _ in range(dim_od)],
    [ 2000 for _ in range(dim_od)]
], device=device, dtype=dtype)
# Out:
# cpu
# 4

# %% [markdown]
# ## Create and simulate a sample of initial input points (i.e., ODs).

# %%
# Sample according to Sobol
sobol = SobolEngine(dim_od, scramble=True)
x_0 = sobol.draw(config["n_init_search"]).to(dtype=dtype).to(device)
# map the normalized into the original parameter space
train_X0 = unnormalize(x_0, bounds)

# %%
ods_epsilon = []
loss_all = []
batch_data_i = []

# Base OD which we will update their count entries
base_od = gt_od_df.copy()
gt_od_vals = gt_od_df['count'].astype(float).to_numpy()

for i , x in enumerate(train_X0.tolist()):
      print(f"########### OD: {i} ###########")
      print(x)
      
      simulation_run_path_init =f'{config["simulation_run_path"]}/initial_search'
      Path(simulation_run_path_init).mkdir(parents=True, exist_ok=True)
      
      new_od_xml = f"{simulation_run_path_init}/init_od_{config['network_name']}_{i}.xml"
      prefix_output_init = f'{simulation_run_path_init}/sobol_{i}'

      # Generate OD
      #curr_od = gt_od_vals.copy()
      curr_od = np.array(x)

      print(f'total expected GT demand: {np.sum(curr_od)}')

      ###
      # create OD xml file 
      ###
      base_od['count'] = curr_od
      # round to 1 decimal point
      base_od['count'] = [round(elem, 1) for elem in base_od['count']]     
      base_od = base_od.rename(columns={'fromTaz':'from', 'toTaz':'to'})        
      create_taz_xml(new_od_xml, base_od, config["od_duration_sec"], base_path)
      ods_epsilon.append(curr_od)

      # simulate initial search
      simulate_od(new_od_xml,
                  prefix_output_init,
                  base_path,
                  config["net_xml"], 
                  config["taz2edge_xml"], 
                  config["additional_xml"],
                  routes_df,
                  config["sim_end_time"],
                  config["TRIPS2ODS_OUT_STR"])

      ## Compute loss
      #prefix_output = f'initial_search/sobol_{i}'
      sim_edge_out = f'{base_path}/{prefix_output_init}_{config["EDGE_OUT_STR"]}'
      print(sim_edge_out)
      curr_loop_stats, _, _ = parse_loop_data_xml_to_pandas(base_path, sim_edge_out,prefix_output_init,config["SUMO_PATH"], edge_list=edge_selection)
      curr_loss = compute_nrmse_counts_all_edges(gt_edge_data, curr_loop_stats)

      loss_all.append(curr_loss)
      print(f"############## loss: {curr_loss} ##############")

      # Parse training data
      df_curr = pd.DataFrame(curr_od.reshape(1,dim_od),
                        columns = [f"x_{i+1}" for i in range(dim_od)])
      df_curr['loss'] = curr_loss
      batch_data_i.append(df_curr)

df_initial_bo = pd.concat(batch_data_i)
# Save initial dataset
df_initial_bo.to_csv(f"{simulation_run_path_init}/data_set_ods_0_2000.csv",index=None)
print(f"save df_initial_bo at {simulation_run_path_init}/data_set_ods_0_2000.csv")
# Out:
# ########### OD: 0 ###########
# [745.6933856010437, 206.5408229827881, 1851.5158891677856, 1965.4040336608887]
# total expected GT demand: 4769.154131412506
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_0_edge_data.xml
# ############## loss: 0.9075635501898125 ##############
# ########### OD: 1 ###########
# [1181.1950206756592, 1300.0009059906006, 569.8890686035156, 391.9411301612854]
# total expected GT demand: 3443.026125431061
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_1.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_1.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_1_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_1_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_1_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_1_edge_data.xml
# ############## loss: 0.6512240571508422 ##############
# ########### OD: 2 ###########
# [1850.9559631347656, 855.464518070221, 1419.0930128097534, 1283.1494808197021]
# total expected GT demand: 5408.662974834442
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_2.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_2.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_2_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_2_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_2_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_2_edge_data.xml
# ############## loss: 1.0334359877749577 ##############
# ########### OD: 3 ###########
# [286.6091728210449, 1636.4245414733887, 137.9563957452774, 855.6906580924988]
# total expected GT demand: 2916.68076813221
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_3.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_3.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_3_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_3_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_3_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_3_edge_data.xml
# ############## loss: 0.681667377979307 ##############
# ########### OD: 4 ###########
# [114.96575176715851, 698.4002590179443, 779.4783115386963, 609.5801591873169]
# total expected GT demand: 2202.424481511116
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_4.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_4.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_4_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_4_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_4_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_4_edge_data.xml
# ############## loss: 0.2627898311404059 ##############
# ########### OD: 5 ###########
# [1554.3431043624878, 1792.3791408538818, 1560.8419179916382, 1060.5396032333374]
# total expected GT demand: 5968.103766441345
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_5.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_5.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_5_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_5_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_5_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_5_edge_data.xml
# ############## loss: 1.213344006080773 ##############
# ########### OD: 6 ###########
# [1477.838158607483, 362.9489541053772, 457.9882621765137, 138.02683353424072]
# total expected GT demand: 2436.8022084236145
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_6.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_6.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_6_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_6_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_6_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_6_edge_data.xml
# ############## loss: 0.6905992044596765 ##############
# ########### OD: 7 ###########
# [917.3060655593872, 1144.42777633667, 1238.8616800308228, 1688.09974193573]
# total expected GT demand: 4988.69526386261
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_7.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_7.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_7_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_7_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_7_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_7_edge_data.xml
# ############## loss: 0.8184491189258492 ##############
# ########### OD: 8 ###########
# [873.7301826477051, 968.3305621147156, 317.5552785396576, 1208.4416151046753]
# total expected GT demand: 3368.0576384067535
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_8.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_8.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_8_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_8_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_8_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_8_edge_data.xml
# ############## loss: 0.43748411394899195 ##############
# ########### OD: 9 ###########
# [1309.2613220214844, 1562.3705387115479, 1098.937749862671, 649.1485834121704]
# total expected GT demand: 4619.7181940078735
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_9.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_9.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_9_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_9_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_9_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_9_edge_data.xml
# ############## loss: 0.8291235735724758 ##############
# ########### OD: 10 ###########
# [1720.9656238555908, 100.66080093383789, 890.595555305481, 1539.1334295272827]
# total expected GT demand: 4251.355409622192
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_10.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_10.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_10_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_10_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_10_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_10_edge_data.xml
# ############## loss: 0.639968432230764 ##############
# ########### OD: 11 ###########
# [156.5893292427063, 1382.2007179260254, 1671.487808227539, 99.46170449256897]
# total expected GT demand: 3309.7395598888397
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_11.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_11.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_11_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_11_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_11_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_11_edge_data.xml
# ############## loss: 0.3046796191570259 ##############
# ########### OD: 12 ###########
# [484.9766492843628, 445.0837969779968, 1309.5145225524902, 368.98282170295715]
# total expected GT demand: 2608.557790517807
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_12.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_12.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_12_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_12_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_12_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_12_edge_data.xml
# ############## loss: 0.27867531712607235 ##############
# ########### OD: 13 ###########
# [1924.322485923767, 1038.604974746704, 27.9069934040308, 1800.893783569336]
# total expected GT demand: 4791.728237643838
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_13.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_13.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_13_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_13_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_13_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_13_edge_data.xml
# ############## loss: 0.9540836065659214 ##############
# ########### OD: 14 ###########
# [1105.8741807937622, 624.2890357971191, 1990.3719425201416, 879.5987963676453]
# total expected GT demand: 4600.133955478668
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_14.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_14.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_14_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_14_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_14_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_14_edge_data.xml
# ############## loss: 0.7714071957841223 ##############
# ########### OD: 15 ###########
# [545.3736186027527, 1905.3101539611816, 709.2546224594116, 1446.7709064483643]
# total expected GT demand: 4606.70930147171
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_15.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_15.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_15_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_15_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_15_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_15_edge_data.xml
# ############## loss: 0.883900045220515 ##############
# ########### OD: 16 ###########
# [614.7237420082092, 538.7355089187622, 1021.9111442565918, 198.15394282341003]
# total expected GT demand: 2373.5243380069733
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_16.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_16.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_16_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_16_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_16_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_16_edge_data.xml
# ############## loss: 0.3602749724729203 ##############
# ########### OD: 17 ###########
# [1054.1000366210938, 1945.2143907546997, 302.7843236923218, 1631.9694519042969]
# total expected GT demand: 4934.068202972412
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_17.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_17.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_17_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_17_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_17_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_17_edge_data.xml
# ############## loss: 1.0704071321564654 ##############
# ########### OD: 18 ###########
# [1978.080153465271, 405.44071793556213, 1715.5559062957764, 554.2447566986084]
# total expected GT demand: 4653.321534395218
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_18.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_18.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_18_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_18_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_18_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_18_edge_data.xml
# ############## loss: 1.029132352100701 ##############
# ########### OD: 19 ###########
# [417.5490140914917, 1124.4195699691772, 996.9192743301392, 1119.3854808807373]
# total expected GT demand: 3658.2733392715454
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_19.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_19.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_19_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_19_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_19_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_19_edge_data.xml
# ############## loss: 0.37712463774224986 ##############
# ########### OD: 20 ###########
# [245.44043838977814, 62.48583272099495, 109.08329486846924, 1349.9137163162231]
# total expected GT demand: 1766.9232822954655
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_20.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_20.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_20_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_20_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_20_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_20_edge_data.xml
# ############## loss: 0.4748899859252006 ##############
# ########### OD: 21 ###########
# [1680.941104888916, 1468.445897102356, 1327.9469013214111, 792.4961447715759]
# total expected GT demand: 5269.830048084259
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_21.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_21.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_21_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_21_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_21_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_21_edge_data.xml
# ############## loss: 1.0393879059017914 ##############
# ########### OD: 22 ###########
# [1351.2089252471924, 882.3160529136658, 661.5256071090698, 1901.5384912490845]
# total expected GT demand: 4796.589076519012
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_22.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_22.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_22_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_22_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_22_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_22_edge_data.xml
# ############## loss: 0.7937195092352582 ##############
# ########### OD: 23 ###########
# [786.8630886077881, 1600.7760763168335, 1879.899024963379, 459.86637473106384]
# total expected GT demand: 4727.404564619064
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_23.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_23.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_23_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_23_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_23_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_23_edge_data.xml
# ############## loss: 0.7426936877195935 ##############
# ########### OD: 24 ###########
# [984.7337007522583, 292.26380586624146, 551.4571666717529, 940.4744505882263]
# total expected GT demand: 2768.929123878479
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_24.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_24.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_24_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_24_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_24_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_24_edge_data.xml
# ############## loss: 0.19373743244491132 ##############
# ########### OD: 25 ###########
# [1424.080491065979, 1198.2849836349487, 1770.3396081924438, 1389.4058465957642]
# total expected GT demand: 5782.110929489136
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_25.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_25.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_25_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_25_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_25_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_25_edge_data.xml
# ############## loss: 1.0961264889587907 ##############
# ########### OD: 26 ###########
# [1606.1171293258667, 644.3125009536743, 248.42974543571472, 310.9458088874817]
# total expected GT demand: 2809.8051846027374
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_26.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_26.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_26_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_26_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_26_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_26_edge_data.xml
# ############## loss: 0.7147050713187388 ##############
# ########### OD: 27 ###########
# [45.615606009960175, 1862.8336191177368, 1466.8220281600952, 1862.9275560379028]
# total expected GT demand: 5238.198809325695
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_27.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_27.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_27_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_27_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_27_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_27_edge_data.xml
# ############## loss: 1.0653717022266573 ##############
# ########### OD: 28 ###########
# [373.4762668609619, 799.8703122138977, 1575.6129026412964, 1609.0569496154785]
# total expected GT demand: 4358.0164313316345
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_28.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_28.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_28_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_28_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_28_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_28_edge_data.xml
# ############## loss: 0.6604936164819126 ##############
# ########### OD: 29 ###########
# [1809.0083599090576, 1706.41028881073, 856.5053939819336, 33.59794244170189]
# total expected GT demand: 4405.521985143423
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/init_od_quickstart_29.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/initial_search/init_od_quickstart_29.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_29_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/initial_search/sobol_29_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_29_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/initial_search/sobol_29_edge_data.xml
# ############## loss: 1.108929902346328 ##############
# save df_initial_bo at output/quickstart_bo_vanilla/initial_search/data_set_ods_0_2000.csv

# %% [markdown]
# ## Run BO epochs

# %%
sampler = StochasticSampler(sample_shape=torch.Size([config["SAMPLE_SHAPE"]]))
df_0 = pd.read_csv(f"{config['simulation_run_path']}/initial_search/data_set_ods_0_2000.csv")

### Run loop
best_value = []

# Data frame of current training data
df_training = df_0
df_training["bo_iteration"] = 0

df_edge_stats = pd.DataFrame()

#num_epsilon_iter = 2
ods_epsilon = []
loss_all = []
batch_data_i = []

# Base OD which we will update their count entries
base_od = gt_od_df.copy()
gt_od_vals = gt_od_df['count'].astype(float).to_numpy()

# TODO for loop for multiple restarts
for i in range(config["NITER"]):
    # new_od_xml = f'{config["simulation_run_path"]}/od.xml'
    #   new_od_xml = f"{simulation_run_path_init}/init_od_{config['network_name']}_{i}.xml"
    #   prefix_output_init = f'{simulation_run_path_init}/sobol_{i}'

    simulation_run_path_BO =f'{config["simulation_run_path"]}/BO'
    Path(simulation_run_path_BO).mkdir(parents=True, exist_ok=True)

    ########
    # Start BO step
    ########

    print(f"########### BO iteration={i+1} ###########")

    # Obtain sampling locations x
    train_X = torch.from_numpy(
        df_training[[col for col in df_training.columns if "x" in col]].values
    ).to(device=device, dtype=dtype)

    # Normalize
    train_X_norm = normalize(train_X,bounds)

    # Obtain reponse data
    train_Y = -torch.from_numpy(df_training[["loss"]].values) # Take negative

    # best value so far
    best_y = train_Y.max()
    best_value.append(best_y)
    print(f"##### best_value={best_y} #####")

    print(f"Generating new sampling location(s)....")
    # Declare model with newest data
    gp_model, gp_mll = initialize_gp_model(train_X_norm,train_Y)

    # Fit model
    fit_gpytorch_mll(gp_mll)

    # Construct acquistion function
    # sampler = StochasticSampler(sample_shape=torch.Size([128]))
    qEI = qLogExpectedImprovement(gp_model, best_f=best_y, sampler=sampler)

    # Maximize acquisition function to get next observation
    x_i = optimize_acqf_and_get_observation(acq_func=qEI,
                                            bounds=bounds,
                                            device=device,
                                            dtype=dtype,
                                            BATCH_SIZE=config["BATCH_SIZE"],
                                            NUM_RESTARTS=config["NUM_RESTARTS"],
                                            RAW_SAMPLES=config["RAW_SAMPLES"])
    
    # if sum(x_i) == 0: skip remainder of loop
    if x_i.sum() == 0:
        print("All zeros, skipping loop")
        continue

    # map the normalized into the original parameter space
    #x_i = unnormalize(x_i, bounds)
    x_i = x_i.cpu().detach().numpy()

    ########
    # End BO step
    ########


    # Sample simulator (inner loop across all sampling locations within a batch)
    batch_data_i = []
    for j in range(config["BATCH_SIZE"]):
        loss_all = []
        print(f"########### Sampling location={j+1} ###########")

        new_od_xml_bo = f"{simulation_run_path_BO}/bayesOpt_od_{config['network_name']}_{i}_{j}.xml"
        prefix_output_bo = f'{simulation_run_path_BO}/bayesOpt_{i}_{j}'

        # Generate OD
        #curr_od = gt_od_vals.copy()
        curr_od = x_i[j]

        print(f'total expected GT demand: {np.sum(curr_od)}')

        base_od['count'] = curr_od
        # round to 1 decimal point
        base_od['count'] = [round(elem, 1) for elem in base_od['count']]
        base_od = base_od.rename(columns={'fromTaz':'from', 'toTaz':'to'})
        create_taz_xml(new_od_xml_bo, base_od, config["od_duration_sec"], base_path)

        # simulate gt od
        simulate_od(new_od_xml_bo,
                    prefix_output_bo,
                    base_path,
                    config["net_xml"],
                    config["taz2edge_xml"],
                    config["additional_xml"],
                    routes_df,
                    config["sim_end_time"],
                    config["TRIPS2ODS_OUT_STR"])

        ## Compute loss
        sim_edge_out = f'{base_path}/{prefix_output_bo}_{config["EDGE_OUT_STR"]}'
        print(sim_edge_out)
        curr_loop_stats, _, _ = parse_loop_data_xml_to_pandas(base_path, sim_edge_out,prefix_output_bo,config["SUMO_PATH"], edge_list=edge_selection)

        curr_loss = compute_nrmse_counts_all_edges(gt_edge_data, curr_loop_stats)
        loss_all.append(curr_loss)
        print(f"############## loss: {curr_loss} ##############")

        # Parse training data
        df_j = pd.DataFrame(x_i[j].reshape(1,dim_od),
                            columns = [f"x_{i+1}" for i in range(dim_od)])
        df_j['loss'] = curr_loss
        batch_data_i.append(df_j)

        curr_loop_stats['bo_iteration'] = i
        curr_loop_stats['batch'] = j
        df_edge_stats = pd.concat([df_edge_stats, curr_loop_stats])

    df_i = pd.concat(batch_data_i)
    df_i["bo_iteration"] = i+1

    df_training = pd.concat([df_training,df_i])
# Out:
# ########### BO iteration=1 ###########
# ##### best_value=-0.1937374324449113 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2426.6322628155717
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_0_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_0_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_0_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_0_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_0_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_0_0_edge_data.xml
# ############## loss: 0.19467846347763235 ##############
# ########### BO iteration=2 ###########
# ##### best_value=-0.1937374324449113 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2700.0062322701233
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_1_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_1_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_1_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_1_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_1_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_1_0_edge_data.xml
# ############## loss: 0.08924189964684857 ##############
# ########### BO iteration=3 ###########
# ##### best_value=-0.08924189964684857 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2688.1854265404354
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_2_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_2_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_2_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_2_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_2_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_2_0_edge_data.xml
# ############## loss: 0.04740564325773492 ##############
# ########### BO iteration=4 ###########
# ##### best_value=-0.04740564325773492 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2000.0
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_3_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_3_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_3_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_3_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_3_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_3_0_edge_data.xml
# ############## loss: 0.6861755281647984 ##############
# ########### BO iteration=5 ###########
# ##### best_value=-0.04740564325773492 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2822.9766690206056
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_4_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_4_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_4_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_4_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_4_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_4_0_edge_data.xml
# ############## loss: 0.13804271209840333 ##############
# ########### BO iteration=6 ###########
# ##### best_value=-0.04740564325773492 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2921.919734897132
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_5_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_5_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_5_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_5_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_5_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_5_0_edge_data.xml
# ############## loss: 0.10655403147226478 ##############
# ########### BO iteration=7 ###########
# ##### best_value=-0.04740564325773492 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2802.984051427593
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_6_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_6_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_6_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_6_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_6_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_6_0_edge_data.xml
# ############## loss: 0.05656181770696682 ##############
# ########### BO iteration=8 ###########
# ##### best_value=-0.04740564325773492 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2667.600651294495
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_7_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_7_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_7_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_7_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_7_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_7_0_edge_data.xml
# ############## loss: 0.06553731361528871 ##############
# ########### BO iteration=9 ###########
# ##### best_value=-0.04740564325773492 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2773.1984016448146
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_8_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_8_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_8_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_8_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_8_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_8_0_edge_data.xml
# ############## loss: 0.02635026437814185 ##############
# ########### BO iteration=10 ###########
# ##### best_value=-0.02635026437814185 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2961.5319130806242
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_9_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_9_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_9_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_9_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_9_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_9_0_edge_data.xml
# ############## loss: 0.09253977235467797 ##############
# ########### BO iteration=11 ###########
# ##### best_value=-0.02635026437814185 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2404.3437004281905
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_10_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_10_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_10_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_10_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_10_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_10_0_edge_data.xml
# ############## loss: 0.14256080845800326 ##############
# ########### BO iteration=12 ###########
# ##### best_value=-0.02635026437814185 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2848.31658064764
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_11_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_11_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_11_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_11_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_11_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_11_0_edge_data.xml
# ############## loss: 0.03453042075814561 ##############
# ########### BO iteration=13 ###########
# ##### best_value=-0.02635026437814185 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 3038.9645202575034
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_12_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_12_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_12_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_12_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_12_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_12_0_edge_data.xml
# ############## loss: 0.09224494204131875 ##############
# ########### BO iteration=14 ###########
# ##### best_value=-0.02635026437814185 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2817.535667574813
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_13_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_13_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_13_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_13_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_13_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_13_0_edge_data.xml
# ############## loss: 0.022984246139111524 ##############
# ########### BO iteration=15 ###########
# ##### best_value=-0.022984246139111524 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 3072.8130104236643
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_14_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_14_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_14_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_14_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_14_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_14_0_edge_data.xml
# ############## loss: 0.20012538335180655 ##############
# ########### BO iteration=16 ###########
# ##### best_value=-0.022984246139111524 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2724.443175459939
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_15_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_15_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_15_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_15_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_15_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_15_0_edge_data.xml
# ############## loss: 0.11432554251054165 ##############
# ########### BO iteration=17 ###########
# ##### best_value=-0.022984246139111524 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2713.327989805111
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_16_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_16_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_16_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_16_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_16_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_16_0_edge_data.xml
# ############## loss: 0.03844285260376049 ##############
# ########### BO iteration=18 ###########
# ##### best_value=-0.022984246139111524 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2786.494144054869
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_17_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_17_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_17_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_17_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_17_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_17_0_edge_data.xml
# ############## loss: 0.03423848536320186 ##############
# ########### BO iteration=19 ###########
# ##### best_value=-0.022984246139111524 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2771.434883093684
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_18_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_18_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_18_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_18_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_18_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_18_0_edge_data.xml
# ############## loss: 0.07192410529910624 ##############
# ########### BO iteration=20 ###########
# ##### best_value=-0.022984246139111524 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2779.317527569461
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_19_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_19_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_19_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_19_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_19_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_19_0_edge_data.xml
# ############## loss: 0.026537267053863726 ##############
# ########### BO iteration=21 ###########
# ##### best_value=-0.022984246139111524 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2564.05108280297
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_20_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_20_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_20_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_20_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_20_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_20_0_edge_data.xml
# ############## loss: 0.0850955407564678 ##############
# ########### BO iteration=22 ###########
# ##### best_value=-0.022984246139111524 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2688.3430321577275
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_21_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_21_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_21_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_21_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_21_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_21_0_edge_data.xml
# ############## loss: 0.15973350587590657 ##############
# ########### BO iteration=23 ###########
# ##### best_value=-0.022984246139111524 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2820.321869675343
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_22_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_22_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_22_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_22_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_22_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_22_0_edge_data.xml
# ############## loss: 0.04755208027125012 ##############
# ########### BO iteration=24 ###########
# ##### best_value=-0.022984246139111524 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 3247.2383539617013
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_23_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_23_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_23_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_23_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_23_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_23_0_edge_data.xml
# ############## loss: 0.26434355447579844 ##############
# ########### BO iteration=25 ###########
# ##### best_value=-0.022984246139111524 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2850.072627340019
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_24_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_24_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_24_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_24_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_24_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_24_0_edge_data.xml
# ############## loss: 0.06613339832207607 ##############
# ########### BO iteration=26 ###########
# ##### best_value=-0.022984246139111524 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2849.8192233695486
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_25_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_25_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_25_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_25_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_25_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_25_0_edge_data.xml
# ############## loss: 0.10117964405914738 ##############
# ########### BO iteration=27 ###########
# ##### best_value=-0.022984246139111524 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2804.399992351502
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_26_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_26_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_26_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_26_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_26_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_26_0_edge_data.xml
# ############## loss: 0.022448400493129027 ##############
# ########### BO iteration=28 ###########
# ##### best_value=-0.022448400493129027 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 3079.748277952753
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_27_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_27_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_27_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_27_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_27_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_27_0_edge_data.xml
# ############## loss: 0.18762282536642083 ##############
# ########### BO iteration=29 ###########
# ##### best_value=-0.022448400493129027 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2864.4746105232457
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_28_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_28_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_28_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_28_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_28_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_28_0_edge_data.xml
# ############## loss: 0.04389721337795781 ##############
# ########### BO iteration=30 ###########
# ##### best_value=-0.022448400493129027 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2969.2842832477763
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_29_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_29_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_29_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_29_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_29_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_29_0_edge_data.xml
# ############## loss: 0.19183039670214183 ##############
# ########### BO iteration=31 ###########
# ##### best_value=-0.022448400493129027 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2849.656837814195
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_30_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_30_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_30_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_30_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_30_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_30_0_edge_data.xml
# ############## loss: 0.0374887979887425 ##############
# ########### BO iteration=32 ###########
# ##### best_value=-0.022448400493129027 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2940.2357841852245
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_31_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_31_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_31_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_31_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_31_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_31_0_edge_data.xml
# ############## loss: 0.059855771989055055 ##############
# ########### BO iteration=33 ###########
# ##### best_value=-0.022448400493129027 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2804.8761707567633
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_32_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_32_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_32_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_32_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_32_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_32_0_edge_data.xml
# ############## loss: 0.036915635697059385 ##############
# ########### BO iteration=34 ###########
# ##### best_value=-0.022448400493129027 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2685.8553665404233
# ...
# ########### BO iteration=90 ###########
# ##### best_value=-0.003938452953287346 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2911.711549818809
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_89_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_89_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_89_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_89_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_89_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_89_0_edge_data.xml
# ############## loss: 0.2356052797465779 ##############
# ########### BO iteration=91 ###########
# ##### best_value=-0.003938452953287346 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 3074.134590206064
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_90_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_90_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_90_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_90_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_90_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_90_0_edge_data.xml
# ############## loss: 0.13907662525495681 ##############
# ########### BO iteration=92 ###########
# ##### best_value=-0.003938452953287346 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 3434.060264195344
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_91_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_91_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_91_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_91_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_91_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_91_0_edge_data.xml
# ############## loss: 0.23392060700243755 ##############
# ########### BO iteration=93 ###########
# ##### best_value=-0.003938452953287346 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2801.091360309538
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_92_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_92_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_92_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_92_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_92_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_92_0_edge_data.xml
# ############## loss: 0.00654976398689477 ##############
# ########### BO iteration=94 ###########
# ##### best_value=-0.003938452953287346 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2487.21051927238
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_93_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_93_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_93_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_93_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_93_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_93_0_edge_data.xml
# ############## loss: 0.16891116173273935 ##############
# ########### BO iteration=95 ###########
# ##### best_value=-0.003938452953287346 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 3066.359895607694
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_94_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_94_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_94_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_94_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_94_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_94_0_edge_data.xml
# ############## loss: 0.18657963746295378 ##############
# ########### BO iteration=96 ###########
# ##### best_value=-0.003938452953287346 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2790.7558054099345
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_95_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_95_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_95_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_95_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_95_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_95_0_edge_data.xml
# ############## loss: 0.0054857072414719495 ##############
# ########### BO iteration=97 ###########
# ##### best_value=-0.003938452953287346 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2584.8374648857043
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_96_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_96_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_96_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_96_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_96_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_96_0_edge_data.xml
# ############## loss: 0.17326607490631396 ##############
# ########### BO iteration=98 ###########
# ##### best_value=-0.003938452953287346 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2880.2026543939364
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_97_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_97_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_97_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_97_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_97_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_97_0_edge_data.xml
# ############## loss: 0.050897274429763904 ##############
# ########### BO iteration=99 ###########
# ##### best_value=-0.003938452953287346 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2873.5736236935227
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_98_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_98_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_98_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_98_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_98_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_98_0_edge_data.xml
# ############## loss: 0.2204098809904128 ##############
# ########### BO iteration=100 ###########
# ##### best_value=-0.003938452953287346 #####
# Generating new sampling location(s)....
# ########### Sampling location=1 ###########
# total expected GT demand: 2797.7053748040044
# Created  C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_99_0.xml
# od2trips  --spread.uniform --taz-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\taz.xml --tazrelation-files output/quickstart_bo_vanilla/BO/bayesOpt_od_quickstart_99_0.xml -o C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_99_0_trips_beforeRteUpdates.xml
# ###### Running SUMO #######
# Seed 0
# sumo --output-prefix output/quickstart_bo_vanilla/BO/bayesOpt_99_0_ --ignore-route-errors=true --net-file=C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\net.xml --routes=C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_99_0_trips.xml -b 0 -e 57600 --additional-files C:\Users\seung\Documents\GIT\BO_UrbanMobility_Benchmark\network\quickstart\additional.xml --duration-log.statistics --xml-validation never --vehroutes routes.vehroutes.xml --verbose --no-warnings --mesosim true --seed 0
# C:/Users/seung/Documents/GIT/BO_UrbanMobility_Benchmark/output/quickstart_bo_vanilla/BO/bayesOpt_99_0_edge_data.xml
# ############## loss: 0.01279594716057642 ##############

# %% [markdown]
# Store outputs

# %%
print(f"saving at {config['simulation_run_path']}/BO/data_set_bayes_opt.csv")
df_training.to_csv(f"{config['simulation_run_path']}/BO/data_set_bayes_opt.csv",index=None)

print(f"saving at {config['simulation_run_path']}/BO/df_edge_stats.csv")
df_edge_stats.to_csv(f"{config['simulation_run_path']}/BO/df_edge_stats.csv",index=None)
# Out:
# saving at output/quickstart_bo_vanilla/BO/data_set_bayes_opt.csv
# saving at output/quickstart_bo_vanilla/BO/df_edge_stats.csv

# %% [markdown]
# # Results analysis

# %% [markdown]
# Read BO outputs

# %%
df_training = pd.read_csv(f"{config['simulation_run_path']}/BO/data_set_bayes_opt.csv")
df_edge_stats = pd.read_csv(f"{config['simulation_run_path']}/BO/df_edge_stats.csv")

# %% [markdown]
# Convergence plots

# %%
df_plot = df_training.query('bo_iteration>0')
x = df_plot['bo_iteration']
y = df_plot['loss'].cummin()

plt.plot(x, y)
#plt.legend(title='Parameter where:')
plt.xlabel('BO epoch')
plt.ylabel('Best NRMSE')
# plt.show()
plt.savefig(f"{config['simulation_run_path']}/bo_nrmse.png")

# %%
if df_edge_stats.batch.drop_duplicates().shape[0] > 1:
    raise('This needs updating once we start using batches')

losses = []
for o1 in range(config["NITER"]): #num_epsilon_iter):
    curr_edge_stats = df_edge_stats[df_edge_stats.bo_iteration == o1]
    df1b = gt_edge_data.merge(curr_edge_stats, on=['edge_id'], how='left', suffixes=('_gt', '_bo'))
    curr_loss = compute_nrmse_counts_all_edges(gt_edge_data, curr_edge_stats)
    losses.append(curr_loss)

# %% [markdown]
# Scatter plots: fit to traffic data
#
# Bar plots: fit to OD data

# %%
# disable interactive mode
plt.ioff()

if df_edge_stats.batch.drop_duplicates().shape[0] > 1:
    raise('This needs updating once we start using batches')

Path(f"{config['simulation_run_path']}/figs").mkdir(parents=True, exist_ok=True)

losses = []
for o1 in range(config["NITER"]): #num_epsilon_iter):
    curr_edge_stats = df_edge_stats[df_edge_stats.bo_iteration == o1]
    df1b = gt_edge_data.merge(curr_edge_stats, on=['edge_id'], how='left', suffixes=('_gt', '_bo'))
    curr_loss = compute_nrmse_counts_all_edges(gt_edge_data, curr_edge_stats)
    losses.append(curr_loss)

    # find idx of min loss
    idx_min = np.argmin(losses)
    o1 = idx_min

    curr_edge_stats = df_edge_stats[df_edge_stats.bo_iteration == o1]
    df1b = gt_edge_data.merge(curr_edge_stats, on=['edge_id'], how='left', suffixes=('_gt', '_bo'))
    curr_loss = compute_nrmse_counts_all_edges(gt_edge_data, curr_edge_stats)

    plt.figure()    
    # plotting diagonal line that represents a perfect data fit
    max_val = np.max([df1b.interval_nVehContrib_gt.max(), df1b.interval_nVehContrib_bo.max()])
    vec = np.arange(max_val)
    plt.plot(vec, vec, 'r-')
    plt.plot(df1b.interval_nVehContrib_gt, df1b.interval_nVehContrib_bo, 'x') 
    # plt.title(f'BO epochs: {o1}; loss: {curr_loss}')
    plt.xlabel('GT edge counts') 
    plt.ylabel('Simulated edge counts') 
    plt.savefig(f"{config['simulation_run_path']}/figs/{o1}_bo_edge_counts.png")


    # plot of fit to GT OD vs ET OD
    plt.figure()
    # get the OD values with the best loss
    curr_od = df_training.query('bo_iteration==@o1').iloc[0][[col for col in df_training.columns if "x" in col]].values
    # bar graph side by side by x axis
    width = 0.35
    plt.bar(np.arange(len(curr_od)), curr_od, width, label='BO')
    plt.bar(np.arange(len(gt_od_vals)) + width, gt_od_vals, width, label='GT')
    plt.legend()
    plt.xlabel('OD pair')
    plt.ylabel('Demand')
    # plt.title(f'BO iteration: {o1}')
    plt.savefig(f"{config['simulation_run_path']}/figs/{o1}_bo_od.png")

# %% [markdown]
# Save "Initial" iteration and "Best" iteration

# %%
# draw a joint seaborn plot for initial (o1 = 0) and best (o1 = idx_min) iteration
import seaborn as sns
import matplotlib.pyplot as plt

o1 = 0
curr_edge_stats = df_edge_stats[df_edge_stats.bo_iteration == o1]
df1b = gt_edge_data.merge(curr_edge_stats, on=['edge_id'], how='left', suffixes=('_gt', '_bo'))
curr_loss = compute_nrmse_counts_all_edges(gt_edge_data, curr_edge_stats)

idx_min = np.argmin(losses)
o2 = idx_min
curr_edge_stats = df_edge_stats[df_edge_stats.bo_iteration == o2]
df2b = gt_edge_data.merge(curr_edge_stats, on=['edge_id'], how='left', suffixes=('_gt', '_bo'))

# define another df to draw joint plot // hue = bo_iteration
df1b['bo_iteration'] = o1
df2b['bo_iteration'] = o2
df1b['type'] = 'initial'
df2b['type'] = 'best'

df_joint = pd.concat([df1b, df2b])

# plotting diagonal line that represents a perfect data fit
max_val = np.max([df1b.interval_nVehContrib_gt.max(), df1b.interval_nVehContrib_bo.max()])
vec = np.arange(max_val)

fig, ax = plt.subplots(nrows = 1 , ncols = 1, figsize=(5, 4))
# initial
sns.scatterplot(data=df1b, x='interval_nVehContrib_gt', y='interval_nVehContrib_bo',ax=ax)
# x label
ax.set_xlabel('GT edge counts')
# y label
ax.set_ylabel('Simulated edge counts')
ax.plot(vec, vec, 'r-')
plt.savefig(f"{config['simulation_run_path']}/{config['network_name']}_jointplot_initial.png")

fig, ax = plt.subplots(nrows = 1 , ncols = 1, figsize=(5, 4))
# best
sns.scatterplot(data=df2b, x='interval_nVehContrib_gt', y='interval_nVehContrib_bo',ax=ax)
# x label
ax.set_xlabel('GT edge counts')
# y label
ax.set_ylabel('Simulated edge counts')
ax.plot(vec, vec, 'r-')
plt.savefig(f"{config['simulation_run_path']}/{config['network_name']}_jointplot_best.png")

# %%
# config["simulation_run_path"] - "bo_vanilla" + "gridsearch"
gridsearch_path = config["simulation_run_path"].replace("bo_vanilla", "gridsearch")

# %%
log_file_path = f'{gridsearch_path}/simulation_log.txt'
data = pd.read_csv(log_file_path, header=None)
len_col = data.shape[1]
data.columns = ["od_index", "loss"] + [f"od_{i}" for i in range(len_col-2)]
data.iloc[:,2:] = data.iloc[:,2:].map(lambda x: round(x, 1))

# %%
# draw a heatmap
import seaborn as sns
import matplotlib.pyplot as plt

# data.od_0 : x-axis
# data.od_1 : y-axis
# data.loss : color
data_temp = data.copy()
# filter 250-750 and 650-1150
# data_temp = data_temp[(data_temp['od_0'] >= 250) & (data_temp['od_0'] <= 750)]
# data_temp = data_temp[(data_temp['od_1'] >= 650) & (data_temp['od_1'] <= 1150)]
fig, ax = plt.subplots(figsize=(10, 8))

heatmap_data = data_temp.pivot_table(index='od_1', columns='od_0', values='loss')
cax = ax.imshow(heatmap_data.values, aspect='auto', cmap='coolwarm', 
                extent=[heatmap_data.columns.min(), heatmap_data.columns.max(), 
                        heatmap_data.index.min(), heatmap_data.index.max()],
                        origin='lower')
fig.colorbar(cax)

# scatter df_training.x_1 df_training.x_2
df_plot = df_training.query('bo_iteration==0')
init_x = df_plot['x_1']
init_y = df_plot['x_2']
ax.scatter(init_x, init_y, color='green', marker='x', s=10, alpha = 0.3)

df_plot = df_training.query('bo_iteration>0')
# Initialize an empty list to hold the indices where the loss has improved
improved_indices = []

# Track the minimum loss observed so far
min_loss_so_far = float('inf')

# Iterate through each row in the filtered DataFrame
for idx, row in df_plot.iterrows():
    # If the current loss is lower than the minimum loss observed so far
    if row['loss'] < min_loss_so_far:
        # Update the minimum loss
        min_loss_so_far = row['loss']
        # Add the current index to the improved indices list
        improved_indices.append(idx)


df_improved = df_plot.loc[improved_indices]

# Get the x_1, x_2, and loss values from the improved rows
x = df_improved['x_1']
y = df_improved['x_2']
loss = df_improved['loss']
iter = df_improved['bo_iteration']

ax.plot(x, y, '-o', c='black', alpha = 0.5)
# put annotation of iter next to red points
for i, txt in enumerate(iter):
    ax.annotate(txt, (x.iloc[i], y.iloc[i]))

# final bo guess (min loss) x_1, x_2 in blue color
idx_min = df_training['loss'].idxmin()
df_final = df_training.loc[idx_min]
final_x = df_final['x_1']
final_y = df_final['x_2']

ax.scatter(final_x, final_y, color='red', marker='o', s=100)

plt.title('NRMSE heatmap')
# plt.show()
plt.savefig(f"{config['simulation_run_path']}/{config['network_name']}_NRMSE_heatmap.png")

# %%
df_training

# %%
heatmap_data
